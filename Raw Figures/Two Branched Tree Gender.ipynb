# %%
from anytree import Node, RenderTree
from anytree.exporter import DotExporter

# %%
allSessions = Node("1562 Total Sessions")

M = Node("Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions ",parent=allSessions)

M1 = Node("M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)", parent=M)
M2 = Node("M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)", parent=M)
M3 = Node("M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)", parent=M)
M4 = Node("M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)", parent=M)


for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# └── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
#     ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
#     ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
#     ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
#     └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)

# %%
#M1_A1 = Node("A1 | 0.128% | 2 Sessions",parent = M1)
#M1_A2 = Node("A2 | 0.640% | 10 Sessions",parent = M1)
#M1_A3 = Node("A3 | 0.704% | 11 Sessions",parent = M1)

M2_A1 = Node("A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)",parent = M2)
M2_A2 = Node("A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)",parent = M2)
M2_A3 = Node("A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)",parent = M2)

#M3_A1 = Node("A1 | 0.768% | 12 Sessions",parent = M3)
M3_A2 = Node("A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)",parent = M3)
M3_A3 = Node("A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)",parent = M3)

M4_A1 = Node("A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)",parent = M4)
M4_A2 = Node("A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)",parent = M4)
M4_A3 = Node("A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)",parent = M4)

for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# └── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
#     ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
#     ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
#     │   ├── A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)
#     │   ├── A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)
#     │   └── A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)
#     ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
#     │   ├── A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)
#     │   └── A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)
#     └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)
#         ├── A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)
#         ├── A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)
#         └── A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)

# %%
#M1_A1_K1 = Node("K1 | 0.000%|0 Sessions",parent = M1_A1)
#M1_A1_K2 = Node("K2 | 0.128%|2 Sessions",parent = M1_A1)
#M1_A1_K3 = Node("K3 | 0.000%|0 Sessions",parent = M1_A1)
#M1_A2_K1 = Node("K1 | 0.000%| Sessions",parent = M1_A2)
#M1_A2_K2 = Node("K2 | 0.064%| Sessions",parent = M1_A2)
#M1_A2_K3 = Node("K3 | 0.576%| Sessions",parent = M1_A2)
#M1_A3_K1 = Node("K1 | 0.448%|7 Sessions",parent = M1_A3)
#M1_A3_K2 = Node("K2 | 0.000%|0 Sessions",parent = M1_A3)
#M1_A3_K3 = Node("K3 | 0.128%|2 Sessions",parent = M1_A3)

#M2_A1_K1 = Node("K1 | 0.576%|9 Sessions",parent = M2_A1)
#M2_A1_K2 = Node("K2 | 0.576%|9 Sessions",parent = M2_A1)
#M2_A1_K3 = Node("K3 | 0.2561%|4 Sessions",parent = M2_A1)
#M2_A2_K1 = Node("K1 | 0.384%|6 Sessions",parent = M2_A2)
#M2_A2_K2 = Node("K2 | 0.256%|4 Sessions",parent = M2_A2)
M2_A2_K3 = Node("K3|71 Sessions|39 F Sess. (54.92%)|32 M Sess. (45.07%)",parent = M2_A2)
M2_A3_K1 = Node("K1|87 Sessions|46 F Sess. (52.87%)|41 M Sess. (47.12%)",parent = M2_A3)
#M2_A3_K2 = Node("K2 | 0.320%|5 Sessions",parent = M2_A3)
M2_A3_K3 = Node("K3|16 Sessions|8 F Sess. (50%)|8 M Sess. (50%)",parent = M2_A3)

#M3_A1_K1 = Node("K1 | 0.064%|1 Sessions",parent = M3_A1)
#M3_A1_K2 = Node("K2 | 0.192%|3 Sessions",parent = M3_A1)
#M3_A1_K3 = Node("K3 | 0.256%|4 Sessions",parent = M3_A1)
#M3_A2_K1 = Node("K1 | 0.064%|1 Sessions",parent = M3_A2)
#M3_A2_K2 = Node("K2 | 0.000%|0 Sessions",parent = M3_A2)
M3_A2_K3 = Node("K3|27 Sessions|13 F Sess. (48.15%)|14 M Sess. (51.85%)",parent = M3_A2)
M3_A3_K1 = Node("K1|19 Sessions| 8 F Sess. (42.11%)|11 M Sess. (57.89%)",parent = M3_A3)
#M3_A3_K2 = Node("K2 | 0.320%|5 Sessions",parent = M3_A3)
#M3_A3_K3 = Node("K3 | 0.256%|4 Sessions",parent = M3_A3)

#M4_A1_K1 = Node("K1 | 0.704%|11 Sessions",parent = M4_A1)
#M4_A1_K2 = Node("K2 | 0.256%|4 Sessions",parent = M4_A1)
#M4_A1_K3 = Node("K3 | 0.512%|8 Sessions",parent = M4_A1)
#M4_A2_K1 = Node("K1 | 0.512%|8 Sessions",parent = M4_A2)
#M4_A2_K2 = Node("K2 | 0.192%|3 Sessions",parent = M4_A2)
M4_A2_K3 = Node("K3|76 Sessions|49 F Sess. (64.47%)|27 M Sess.(35.53%)",parent = M4_A2)
M4_A3_K1 = Node("K1|102 Sessions|63 F Sess. (61.76%)|39 M Sess. (38.24%)",parent = M4_A3)
#M4_A3_K2 = Node("K2 | 0.384%|6 Sessions",parent = M4_A3)
#M4_A3_K3 = Node("K3 | 0.5762%|9 Sessions",parent = M4_A3)


for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# └── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
#     ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
#     ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
#     │   ├── A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)
#     │   ├── A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)
#     │   │   └── K3|71 Sessions|39 F Sess. (54.92%)|32 M Sess. (45.07%)
#     │   └── A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)
#     │       ├── K1|87 Sessions|46 F Sess. (52.87%)|41 M Sess. (47.12%)
#     │       └── K3|16 Sessions|8 F Sess. (50%)|8 M Sess. (50%)
#     ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
#     │   ├── A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)
#     │   │   └── K3|27 Sessions|13 F Sess. (48.15%)|14 M Sess. (51.85%)
#     │   └── A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)
#     │       └── K1|19 Sessions| 8 F Sess. (42.11%)|11 M Sess. (57.89%)
#     └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)
#         ├── A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)
#         ├── A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)
#         │   └── K3|76 Sessions|49 F Sess. (64.47%)|27 M Sess.(35.53%)
#         └── A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)
#             └── K1|102 Sessions|63 F Sess. (61.76%)|39 M Sess. (38.24%)

# %%
#M2_A2_K3_H1 = Node("H1 |0.640%|10 Sessions",parent = M2_A2_K3)
#M2_A2_K3_H2 = Node("H | %|0 Sessions",parent = M2_A2_K3)
M2_A2_K3_H3 = Node("H3|25 Sessions|16 F Sess. (64%)|9 M Sess. (36%)",parent = M2_A2_K3)
#M2_A2_K3_H4 = Node("H | %|5 Sessions",parent = M2_A2_K3)

#M2_A3_K1_H1 = Node("H1 |0.448%|7 Sessions",parent = M2_A3_K1)
#M2_A3_K1_H2 = Node("H2 |0.064%|1 Sessions",parent = M2_A3_K1)
M2_A3_K1_H3 = Node("H3|32 Sessions|21 F Sess. (65.62%)|11 M Sess. (34.38%)",parent = M2_A3_K1)
#M2_A3_K1_H4 = Node("H4 |0.704%|11 Sessions",parent = M2_A3_K1)

#M4_A2_K3_H1 = Node("H1|0.320%|5 Sessions",parent = M4_A2_K3)
#M4_A2_K3_H2 = Node("H2|0.064%|1 Sessions",parent = M4_A2_K3)
M4_A2_K3_H3 = Node("H3|38 Sessions|25 F Sess. (65.79%)|13 M Sess. (34.21%)",parent = M4_A2_K3)
#M4_A2_K3_H4 = Node("H4|0.384%|6 Sessions",parent = M4_A2_K3)

#M4_A3_K1_H1 = Node("H1|0.320%|5 Sessions",parent = M4_A3_K1)
#M4_A3_K1_H2 = Node("H2|0.064%|1 Sessions",parent = M4_A3_K1)
M4_A3_K1_H3 = Node("H3|38 Sessions|28 F Sess. (73.68%)|10 M Sess. (26.32%)",parent = M4_A3_K1)
#M4_A3_K1_H4 = Node("H4|0.640%|10 Sessions",parent = M4_A3_K1)

for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# └── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
#     ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
#     ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
#     │   ├── A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)
#     │   ├── A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)
#     │   │   └── K3|71 Sessions|39 F Sess. (54.92%)|32 M Sess. (45.07%)
#     │   │       └── H3|25 Sessions|16 F Sess. (64%)|9 M Sess. (36%)
#     │   └── A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)
#     │       ├── K1|87 Sessions|46 F Sess. (52.87%)|41 M Sess. (47.12%)
#     │       │   └── H3|32 Sessions|21 F Sess. (65.62%)|11 M Sess. (34.38%)
#     │       └── K3|16 Sessions|8 F Sess. (50%)|8 M Sess. (50%)
#     ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
#     │   ├── A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)
#     │   │   └── K3|27 Sessions|13 F Sess. (48.15%)|14 M Sess. (51.85%)
#     │   └── A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)
#     │       └── K1|19 Sessions| 8 F Sess. (42.11%)|11 M Sess. (57.89%)
#     └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)
#         ├── A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)
#         ├── A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)
#         │   └── K3|76 Sessions|49 F Sess. (64.47%)|27 M Sess.(35.53%)
#         │       └── H3|38 Sessions|25 F Sess. (65.79%)|13 M Sess. (34.21%)
#         └── A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)
#             └── K1|102 Sessions|63 F Sess. (61.76%)|39 M Sess. (38.24%)
#                 └── H3|38 Sessions|28 F Sess. (73.68%)|10 M Sess. (26.32%)

# %%
A = Node("Travel Pixel Max Vs Shift (A)| 21.38% of Total Sessions|334 Sessions Not in M",parent=allSessions)

A1 = Node("A1|46 Sessions|19 F Sess. (41.30%)|27 M Sess. (58.70%)", parent=A)
A2 = Node("A2|156 Sessions|81 F Sess. (51.92%)|75 M Sess. (48.08%)", parent=A)
A3 = Node("A3|132 Sessions|59 F Sess. (44.70%)|73 M Sess. (55.30%)", parent=A)

for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# ├── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
# │   ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
# │   ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
# │   │   ├── A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)
# │   │   ├── A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)
# │   │   │   └── K3|71 Sessions|39 F Sess. (54.92%)|32 M Sess. (45.07%)
# │   │   │       └── H3|25 Sessions|16 F Sess. (64%)|9 M Sess. (36%)
# │   │   └── A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)
# │   │       ├── K1|87 Sessions|46 F Sess. (52.87%)|41 M Sess. (47.12%)
# │   │       │   └── H3|32 Sessions|21 F Sess. (65.62%)|11 M Sess. (34.38%)
# │   │       └── K3|16 Sessions|8 F Sess. (50%)|8 M Sess. (50%)
# │   ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
# │   │   ├── A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)
# │   │   │   └── K3|27 Sessions|13 F Sess. (48.15%)|14 M Sess. (51.85%)
# │   │   └── A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)
# │   │       └── K1|19 Sessions| 8 F Sess. (42.11%)|11 M Sess. (57.89%)
# │   └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)
# │       ├── A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)
# │       ├── A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)
# │       │   └── K3|76 Sessions|49 F Sess. (64.47%)|27 M Sess.(35.53%)
# │       │       └── H3|38 Sessions|25 F Sess. (65.79%)|13 M Sess. (34.21%)
# │       └── A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)
# │           └── K1|102 Sessions|63 F Sess. (61.76%)|39 M Sess. (38.24%)
# │               └── H3|38 Sessions|28 F Sess. (73.68%)|10 M Sess. (26.32%)
# └── Travel Pixel Max Vs Shift (A)| 21.38% of Total Sessions|334 Sessions Not in M
#     ├── A1|46 Sessions|19 F Sess. (41.30%)|27 M Sess. (58.70%)
#     ├── A2|156 Sessions|81 F Sess. (51.92%)|75 M Sess. (48.08%)
#     └── A3|132 Sessions|59 F Sess. (44.70%)|73 M Sess. (55.30%)

# %%
#A1_D1 = Node("D1|0.192%|3 Sessions",parent = A1)
A1_D2 = Node("D2|29 Sessions |14 F Sess. (48.28%)|15 M Sess.(51.72%) ",parent = A1)
#A1_D3 = Node("D3|0.256%|4 Sessions",parent = A1)

#A1_D1 = Node("D1|0.192%|3 Sessions",parent = A1)
A2_D2 = Node("D2|54 Sessions|27 F Sess. (50.00%)|27 M Sess. (50.00%)",parent = A2)
#A2_D3 = Node("D3|0.832%|13 Sessions",parent = A2)



#A3_D1 = Node("D1|0.448%|7 Sessions",parent = A3)
A3_D2 = Node("D2|42 Sessions|17 F Sess. (40.48%)|25 M Sess. (59.52%)",parent = A3)
#A3_D3 = Node("D3|0.640%|10 Sessions",parent = A3)

for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# ├── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
# │   ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
# │   ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
# │   │   ├── A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)
# │   │   ├── A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)
# │   │   │   └── K3|71 Sessions|39 F Sess. (54.92%)|32 M Sess. (45.07%)
# │   │   │       └── H3|25 Sessions|16 F Sess. (64%)|9 M Sess. (36%)
# │   │   └── A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)
# │   │       ├── K1|87 Sessions|46 F Sess. (52.87%)|41 M Sess. (47.12%)
# │   │       │   └── H3|32 Sessions|21 F Sess. (65.62%)|11 M Sess. (34.38%)
# │   │       └── K3|16 Sessions|8 F Sess. (50%)|8 M Sess. (50%)
# │   ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
# │   │   ├── A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)
# │   │   │   └── K3|27 Sessions|13 F Sess. (48.15%)|14 M Sess. (51.85%)
# │   │   └── A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)
# │   │       └── K1|19 Sessions| 8 F Sess. (42.11%)|11 M Sess. (57.89%)
# │   └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)
# │       ├── A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)
# │       ├── A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)
# │       │   └── K3|76 Sessions|49 F Sess. (64.47%)|27 M Sess.(35.53%)
# │       │       └── H3|38 Sessions|25 F Sess. (65.79%)|13 M Sess. (34.21%)
# │       └── A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)
# │           └── K1|102 Sessions|63 F Sess. (61.76%)|39 M Sess. (38.24%)
# │               └── H3|38 Sessions|28 F Sess. (73.68%)|10 M Sess. (26.32%)
# └── Travel Pixel Max Vs Shift (A)| 21.38% of Total Sessions|334 Sessions Not in M
#     ├── A1|46 Sessions|19 F Sess. (41.30%)|27 M Sess. (58.70%)
#     │   └── D2|29 Sessions |14 F Sess. (48.28%)|15 M Sess.(51.72%)
#     ├── A2|156 Sessions|81 F Sess. (51.92%)|75 M Sess. (48.08%)
#     │   └── D2|54 Sessions|27 F Sess. (50.00%)|27 M Sess. (50.00%)
#     └── A3|132 Sessions|59 F Sess. (44.70%)|73 M Sess. (55.30%)
#         └── D2|42 Sessions|17 F Sess. (40.48%)|25 M Sess. (59.52%)

# %%
#A1_D2_H1 = Node("H1|0.128%|2 Sessions",parent =A1_D2)
#A1_D2_H2 = Node("H2|0.064%|1 Sessions",parent =A1_D2)
#A1_D2_H3 = Node("H3|0.896%|14 Sessions",parent =A1_D2)
#A1_D2_H4 = Node("H4|0.064%|1 Sessions",parent =A1_D2)

#A2_D2_H1 = Node("H1|0.320%|5 Sessions",parent =A2_D2)
#A2_D2_H2 = Node("H2|0.640%|1 Sessions",parent =A2_D2)
#A2_D2_H3 = Node("H3|1.665%|26 Sessions",parent =A2_D2)
#A2_D2_H4 = Node("H4|0.256%|4Sessions",parent =A2_D2)

#A3_D2_H1 = Node("H1|0.256%|4 Sessions",parent =A3_D2)
#A3_D2_H2 = Node("H2|0.000%|0 Sessions",parent =A3_D2)
#A3_D2_H3 = Node("H3|1.216%|19 Sessions",parent =A3_D2)
#A3_D2_H4 = Node("H4|0.320%|5 Sessions",parent =A3_D2)

for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# ├── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
# │   ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
# │   ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
# │   │   ├── A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)
# │   │   ├── A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)
# │   │   │   └── K3|71 Sessions|39 F Sess. (54.92%)|32 M Sess. (45.07%)
# │   │   │       └── H3|25 Sessions|16 F Sess. (64%)|9 M Sess. (36%)
# │   │   └── A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)
# │   │       ├── K1|87 Sessions|46 F Sess. (52.87%)|41 M Sess. (47.12%)
# │   │       │   └── H3|32 Sessions|21 F Sess. (65.62%)|11 M Sess. (34.38%)
# │   │       └── K3|16 Sessions|8 F Sess. (50%)|8 M Sess. (50%)
# │   ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
# │   │   ├── A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)
# │   │   │   └── K3|27 Sessions|13 F Sess. (48.15%)|14 M Sess. (51.85%)
# │   │   └── A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)
# │   │       └── K1|19 Sessions| 8 F Sess. (42.11%)|11 M Sess. (57.89%)
# │   └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)
# │       ├── A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)
# │       ├── A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)
# │       │   └── K3|76 Sessions|49 F Sess. (64.47%)|27 M Sess.(35.53%)
# │       │       └── H3|38 Sessions|25 F Sess. (65.79%)|13 M Sess. (34.21%)
# │       └── A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)
# │           └── K1|102 Sessions|63 F Sess. (61.76%)|39 M Sess. (38.24%)
# │               └── H3|38 Sessions|28 F Sess. (73.68%)|10 M Sess. (26.32%)
# └── Travel Pixel Max Vs Shift (A)| 21.38% of Total Sessions|334 Sessions Not in M
#     ├── A1|46 Sessions|19 F Sess. (41.30%)|27 M Sess. (58.70%)
#     │   └── D2|29 Sessions |14 F Sess. (48.28%)|15 M Sess.(51.72%)
#     ├── A2|156 Sessions|81 F Sess. (51.92%)|75 M Sess. (48.08%)
#     │   └── D2|54 Sessions|27 F Sess. (50.00%)|27 M Sess. (50.00%)
#     └── A3|132 Sessions|59 F Sess. (44.70%)|73 M Sess. (55.30%)
#         └── D2|42 Sessions|17 F Sess. (40.48%)|25 M Sess. (59.52%)

# %%
#A1_H1 = Node("H1|0.256%|4 Sessions",parent = A1)
#A1_H2 = Node("H2|0.064%|1 Sessions",parent = A1)
A1_H3 = Node("H3|18 Sessions|7 F Sess. (38.89%)|11 M Sess. (61.11%)",parent = A1)
#A1_H4 = Node("H4|0.192%|3 Sessions",parent = A)

A2_H1 = Node("H1|18 Sessions|6 F Sess. (33.33%)|12 M Sess. (66.67%)",parent = A2)
#A2_H2 = Node("H2|0.320%|5 Sessions",parent = A2)
A2_H3 = Node("H3|66 Sessions|38 F Sess. (57.58%)|28 M Sess. (42.42%)",parent = A2)
#A2_H4 = Node("H4|0.512%|8 Sessions",parent = A2)

#A3_H1 = Node("H1|0.640%|10 Sessions",parent = A3)
#A3_H2 = Node("H2|0.128%|2 Sessions",parent = A3)
A3_H3 = Node("H3|61 Sessions|31 F Sess. (50.82%)|30 M Sess. (49.18%)",parent = A3)
#A3_H4 = Node("H4|0.704%|11 Sessions",parent = A3)

for pre, fill, node in RenderTree(allSessions):
    print("%s%s" % (pre, node.name))
# Out:
# 1562 Total Sessions
# ├── Reward Choice Max Vs Shift (M)| 72.023% of Total Sessions|1125 Sessions
# │   ├── M1|40 Sessions |21 F Sess. (52.5%)|19 M Sess. (47.5%)
# │   ├── M2|489 Sessions|245 F Sess. (50.1%)|244 M Sess. (49.9%)
# │   │   ├── A1 |28 Sessions|11 F Sess. (39.29%)|17 M Sess. (60.71%)
# │   │   ├── A2 |84 Sessions|45 F Sess. (53.57%)|39 M Sess. (46.43%)
# │   │   │   └── K3|71 Sessions|39 F Sess. (54.92%)|32 M Sess. (45.07%)
# │   │   │       └── H3|25 Sessions|16 F Sess. (64%)|9 M Sess. (36%)
# │   │   └── A3 |113 Sessions|56 F Sess. (49.55)|57 M Sess. (50.45%)
# │   │       ├── K1|87 Sessions|46 F Sess. (52.87%)|41 M Sess. (47.12%)
# │   │       │   └── H3|32 Sessions|21 F Sess. (65.62%)|11 M Sess. (34.38%)
# │   │       └── K3|16 Sessions|8 F Sess. (50%)|8 M Sess. (50%)
# │   ├── M3|164 Sessions|64 F Sess. (39.02%)|100 M Sess. (60.98%)
# │   │   ├── A2 |28 Sessions|13 F Sess. (46.43%)|15 M Sess. (53.57%)
# │   │   │   └── K3|27 Sessions|13 F Sess. (48.15%)|14 M Sess. (51.85%)
# │   │   └── A3 |31 Sessions|11 F Sess. (35.48%)|20 M Sess. (64.52%)
# │   │       └── K1|19 Sessions| 8 F Sess. (42.11%)|11 M Sess. (57.89%)
# │   └── M4|432 Sessions|254 F Sess. (58.8%)|178 M Sess. (41.2%)
# │       ├── A1 |27 Sessions|12 F Sess. (44.44%)|15 M Sess. (55.56%)
# │       ├── A2 |87 Sessions|57 F Sess. (65.52%)|30 M Sess. (34.48%)
# │       │   └── K3|76 Sessions|49 F Sess. (64.47%)|27 M Sess.(35.53%)
# │       │       └── H3|38 Sessions|25 F Sess. (65.79%)|13 M Sess. (34.21%)
# │       └── A3 |122 Sessions|72 F Sess. (59.01%)|50 M Sess. (40.99%)
# │           └── K1|102 Sessions|63 F Sess. (61.76%)|39 M Sess. (38.24%)
# │               └── H3|38 Sessions|28 F Sess. (73.68%)|10 M Sess. (26.32%)
# └── Travel Pixel Max Vs Shift (A)| 21.38% of Total Sessions|334 Sessions Not in M
#     ├── A1|46 Sessions|19 F Sess. (41.30%)|27 M Sess. (58.70%)
#     │   ├── D2|29 Sessions |14 F Sess. (48.28%)|15 M Sess.(51.72%)
#     │   └── H3|18 Sessions|7 F Sess. (38.89%)|11 M Sess. (61.11%)
#     ├── A2|156 Sessions|81 F Sess. (51.92%)|75 M Sess. (48.08%)
#     │   ├── D2|54 Sessions|27 F Sess. (50.00%)|27 M Sess. (50.00%)
#     │   ├── H1|18 Sessions|6 F Sess. (33.33%)|12 M Sess. (66.67%)
#     │   └── H3|66 Sessions|38 F Sess. (57.58%)|28 M Sess. (42.42%)
#     └── A3|132 Sessions|59 F Sess. (44.70%)|73 M Sess. (55.30%)
#         ├── D2|42 Sessions|17 F Sess. (40.48%)|25 M Sess. (59.52%)
#         └── H3|61 Sessions|31 F Sess. (50.82%)|30 M Sess. (49.18%)

# %%
DotExporter(allSessions).to_picture("Gender tree.pdf")
